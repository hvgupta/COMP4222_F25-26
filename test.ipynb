# %%
from app.market_data_fetcher.fmp_functions import get_historical_data_for_company

# %%
a = get_historical_data_for_company("AAPL", "2025-10-01", "2025-11-01")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = get_historical_data_for_company("AAPL", "2023-01-01", "2023-12-31")
#
# File ~/COMP4222/COMP4222_F25-26/app/market_data_fetcher/fmp_functions.py:26, in get_historical_data_for_company(ticker_symbol, start_date, end_date)
#      25 def get_historical_data_for_company(ticker_symbol: str, start_date: str, end_date: str):
# ---> 26     return call_fmp_api(
#      27         "historical-price-eod",
#      28         {
#      29             "symbol": ticker_symbol,
#      30             "from": start_date,
#      31             "to": end_date
#      32         }
#      33     )
#
# File ~/COMP4222/COMP4222_F25-26/app/market_data_fetcher/fmp_functions.py:19, in call_fmp_api(function_name, params)
#      14 params["apikey"] = fmp_api_key
#      15 response = requests.get(
# ...
